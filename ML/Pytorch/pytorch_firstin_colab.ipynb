# %%
import torch

torch.__version__
# Out:
# '1.11.0+cu113'

# %%
x=torch.empty(4,2)

# %%
x
# Out:
# tensor([[1.0901e-34, 0.0000e+00],
#         [3.3631e-44, 0.0000e+00],
#         [       nan, 0.0000e+00],
#         [1.1578e+27, 1.1362e+30]])

# %%
x=torch.rand(4,2)

# %%
x
# Out:
# tensor([[0.3720, 0.7700],
#         [0.3324, 0.4954],
#         [0.9564, 0.3868],
#         [0.2624, 0.3410]])

# %%
x=torch.zeros(4,2,dtype=torch.long)

# %%
x
# Out:
# tensor([[0, 0],
#         [0, 0],
#         [0, 0],
#         [0, 0]])

# %%
x=torch.tensor([3,2.3])

# %%
x
# Out:
# tensor([3.0000, 2.3000])

# %%
x=x.new_ones(2,4,dtype=torch.double)

# %%
x
# Out:
# tensor([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]], dtype=torch.float64)

# %%
x=torch.randn_like(x,dtype=torch.float)

# %%
x
# Out:
# tensor([[ 0.6985, -0.2009, -0.2430, -0.9190],
#         [-0.8151,  0.0975, -0.2498,  0.5547]])

# %%
print(x.size())
# Out:
# torch.Size([2, 4])

# %%
ft=torch.FloatTensor([1,2,3])
print(ft)
print(ft.dtype)
# Out:
# tensor([1., 2., 3.])
# torch.float32

# %%
print(ft.short())
print(ft.int())
print(ft.long())
# Out:
# tensor([1, 2, 3], dtype=torch.int16)
# tensor([1, 2, 3], dtype=torch.int32)
# tensor([1, 2, 3])

# %%
it=torch.IntTensor([1,2,3])
print(it)
print(it.dtype)
# Out:
# tensor([1, 2, 3], dtype=torch.int32)
# torch.int32

# %%
print(it.float())
print(it.double())
print(it.half())
# Out:
# tensor([1., 2., 3.])
# tensor([1., 2., 3.], dtype=torch.float64)
# tensor([1., 2., 3.], dtype=torch.float16)

# %%
x=torch.randn(1)
print(x)
print(x.item())
print(x.dtype)
# Out:
# tensor([1.1429])
# 1.1429414749145508
# torch.float32

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
y=torch.ones_like(x,device=device)
print(y)
x=x.to(device)
print(x)
z=x+y
print(z)
print(z.to('cpu', torch.double))
# Out:
# cuda
# tensor([1.], device='cuda:0')
# tensor([1.1429], device='cuda:0')
# tensor([2.1429], device='cuda:0')
# tensor([2.1429], dtype=torch.float64)

# %%
t0=torch.tensor(0)
print(t0.ndim)
print(t0.shape)
print(t0)
# Out:
# 0
# torch.Size([])
# tensor(0)

# %%
t1=torch.tensor([1,2,3])
print(t1.ndim)
print(t1.shape)
print(t1)
# Out:
# 1
# torch.Size([3])
# tensor([1, 2, 3])

# %%
t2=torch.tensor([[1,2,3],
                 [2,3,4]])
print(t2.ndim)
print(t2.shape)
print(t2)
# Out:
# 2
# torch.Size([2, 3])
# tensor([[1, 2, 3],
#         [2, 3, 4]])

# %%
t3=torch.tensor([[[1,2,3],
                  [2,4,6]],
                 [[6,7,8],
                 [9,8,7]]])
print(t3.ndim)
print(t3.shape)
print(t3)
# Out:
# 3
# torch.Size([2, 2, 3])
# tensor([[[1, 2, 3],
#          [2, 4, 6]],
#
#         [[6, 7, 8],
#          [9, 8, 7]]])

# %%
import math

a=torch.rand(1,2)*2-1
print(a)
print(torch.abs(a))
print(torch.ceil(a))
print(torch.floor(a))
print(torch.clamp(a,-0.5,0.5))
# Out:
# tensor([[-0.3352,  0.6125]])
# tensor([[0.3352, 0.6125]])
# tensor([[-0., 1.]])
# tensor([[-1.,  0.]])
# tensor([[-0.3352,  0.5000]])

# %%
x=torch.rand(2,2)
print(x)
print(x.max(dim=0))
print(x.max(dim=1))
# Out:
# tensor([[0.7777, 0.4844],
#         [0.5709, 0.1529]])
# torch.return_types.max(
# values=tensor([0.7777, 0.4844]),
# indices=tensor([0, 0]))
# torch.return_types.max(
# values=tensor([0.7777, 0.5709]),
# indices=tensor([0, 0]))

# %%
print(x)
print(x.min(dim=0))
print(x.max(dim=1))
# Out:
# tensor([[0.7777, 0.4844],
#         [0.5709, 0.1529]])
# torch.return_types.min(
# values=tensor([0.5709, 0.1529]),
# indices=tensor([1, 1]))
# torch.return_types.max(
# values=tensor([0.7777, 0.5709]),
# indices=tensor([0, 0]))

# %%
x=torch.rand(2,2)
print(x)
y=torch.rand(2,2)
print(y)
# Out:
# tensor([[0.9296, 0.1259],
#         [0.1944, 0.4402]])
# tensor([[0.6234, 0.6008],
#         [0.6353, 0.0774]])

# %%
print(x+y)
print(torch.add(x,y))
# Out:
# tensor([[1.5530, 0.7267],
#         [0.8298, 0.5176]])
# tensor([[1.5530, 0.7267],
#         [0.8298, 0.5176]])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
result=torch.empty(2,4)
torch.add(x,y,out=result)
print(result)
# Out:
# tensor([[1.5530, 0.7267],
#         [0.8298, 0.5176]])
